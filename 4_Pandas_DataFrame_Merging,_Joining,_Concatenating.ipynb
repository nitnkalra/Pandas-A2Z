# %%
import pandas as pd
import numpy as np

# %%
courses = pd.read_csv('/content/courses.csv')
delivery = pd.read_csv('/content/deliveries.csv')
matches = pd.read_csv('/content/matches.csv')
nov = pd.read_csv('/content/reg-month1.csv')
dec = pd.read_csv('/content/reg-month2.csv')
students = pd.read_csv('/content/students.csv',encoding='latin-1')

# %% [markdown]
# ## Concat

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
#there are 2 files nov & dec, adding both nov & dec into 1 file
#pd.concat() --> vertically stack

pd.concat([nov,dec])    #--> veritcally merged but index is repeating
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
regs = pd.concat([nov,dec],ignore_index=True)
regs
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# 34          11          8
# 35          14          6
# 36          12          5
# 37          12          7
# 38          18          8
# 39           1         10
# 40           1          9
# 41           2          5
# 42           7          6
# 43          22          5
# 44          22          6
# 45          23          9
# 46          23          5
# 47          14          4
# 48          14          1
# 49          11         10
# 50          42          9
# 51          50          8
# 52          38          1

# %%
#another way to concat

nov.append(dec,ignore_index=True)
# Out:
# <ipython-input-17-f604aae35210>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nov.append(dec,ignore_index=True)
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# 34          11          8
# 35          14          6
# 36          12          5
# 37          12          7
# 38          18          8
# 39           1         10
# 40           1          9
# 41           2          5
# 42           7          6
# 43          22          5
# 44          22          6
# 45          23          9
# 46          23          5
# 47          14          4
# 48          14          1
# 49          11         10
# 50          42          9
# 51          50          8
# 52          38          1

# %%
#what if i want to keep original index
#multi index dataframe

multi = pd.concat([nov,dec],keys=['Nov','Dec'])
multi
# Out:
#         student_id  course_id
# Nov 0           23          1
#     1           15          5
#     2           18          6
#     3           23          4
#     4           16          9
#     5           18          1
#     6            1          1
#     7            7          8
#     8           22          3
#     9           15          1
#     10          19          4
#     11           1          6
#     12           7         10
#     13          11          7
#     14          13          3
#     15          24          4
#     16          21          1
#     17          16          5
#     18          23          3
#     19          17          7
#     20          23          6
#     21          25          1
#     22          19          2
#     23          25         10
#     24           3          3
# Dec 0            3          5
#     1           16          7
#     2           12         10
#     3           12          1
#     4           14          9
#     5            7          7
#     6            7          2
#     7           16          3
#     8           17         10
#     9           11          8
#     10          14          6
#     11          12          5
#     12          12          7
#     13          18          8
#     14           1         10
#     15           1          9
#     16           2          5
#     17           7          6
#     18          22          5
#     19          22          6
#     20          23          9
#     21          23          5
#     22          14          4
#     23          14          1
#     24          11         10
#     25          42          9
#     26          50          8
#     27          38          1

# %%
#how to extract multi index dataframe based on thier index's

multi.loc['Dec']
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
#how to extract value inside nov

multi.loc[('Nov',4)]
# Out:
# student_id    16
# course_id      9
# Name: (Nov, 4), dtype: int64

# %%
#stacking data horizontally vs vertically

pd.concat([nov,dec],axis=1)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# 18        23.0        3.0          22          5
# 19        17.0        7.0          22          6
# 20        23.0        6.0          23          9
# 21        25.0        1.0          23          5
# 22        19.0        2.0          14          4
# 23        25.0       10.0          14          1
# 24         3.0        3.0          11         10
# 25         NaN        NaN          42          9
# 26         NaN        NaN          50          8
# 27         NaN        NaN          38          1

# %%
pd.concat([nov,dec],axis=1).shape
# Out:
# (28, 4)

# %% [markdown]
# ## Merge

# %%
#there are 2 tables: students & regs. I want to join regs with students on the basis of student_id to forma a new table which will have both table info

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# there are 4 ways to join:
#
# 1. inner join
# 2. outer join
# 3. left join
# 4. right join

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#inner join
#items present in both table

students.merge(regs,how='inner',on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23          1
# 1            1       Kailash Harjo       23          6
# 2            1       Kailash Harjo       23         10
# 3            1       Kailash Harjo       23          9
# 4            2         Esha Butala        1          5
# 5            3      Parveen Bhalla        3          3
# 6            3      Parveen Bhalla        3          5
# 7            7        Tarun Thaker        9          8
# 8            7        Tarun Thaker        9         10
# 9            7        Tarun Thaker        9          7
# 10           7        Tarun Thaker        9          2
# 11           7        Tarun Thaker        9          6
# 12          11  David Mukhopadhyay       20          7
# 13          11  David Mukhopadhyay       20          8
# 14          11  David Mukhopadhyay       20         10
# 15          12          Radha Dutt       19         10
# 16          12          Radha Dutt       19          1
# 17          12          Radha Dutt       19          5
# 18          12          Radha Dutt       19          7
# 19          13      Munni Varghese       24          3
# 20          14    Pranab Natarajan       22          9
# 21          14    Pranab Natarajan       22          6
# 22          14    Pranab Natarajan       22          4
# 23          14    Pranab Natarajan       22          1
# 24          15           Preet Sha       16          5
# 25          15           Preet Sha       16          1
# 26          16        Elias Dodiya       25          9
# 27          16        Elias Dodiya       25          5
# 28          16        Elias Dodiya       25          7
# 29          16        Elias Dodiya       25          3
# 30          17        Yasmin Palan        7          7
# 31          17        Yasmin Palan        7         10
# 32          18     Fardeen Mahabir       13          6
# 33          18     Fardeen Mahabir       13          1
# 34          18     Fardeen Mahabir       13          8
# 35          19        Qabeel Raman       12          4
# 36          19        Qabeel Raman       12          2
# 37          21          Seema Kota       15          1
# 38          22          Yash Sethi       21          3
# 39          22          Yash Sethi       21          5
# 40          22          Yash Sethi       21          6
# 41          23      Chhavi Lachman       18          1
# 42          23      Chhavi Lachman       18          4
# 43          23      Chhavi Lachman       18          3
# 44          23      Chhavi Lachman       18          6
# 45          23      Chhavi Lachman       18          9
# 46          23      Chhavi Lachman       18          5
# 47          24        Radhika Suri       17          4
# 48          25     Shashank DAlia        2          1
# 49          25     Shashank DAlia        2         10

# %%
#left
#left data will print in table whether its present in right table or not
#same as below numpy & c++ is visible but values are NaN
#if it would be inner join, then it will not print bcoz inner will only print
#if its available in both table


courses.merge(regs,how='left',on='course_id')
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        23.0
# 1           1            python   2499        18.0
# 2           1            python   2499         1.0
# 3           1            python   2499        15.0
# 4           1            python   2499        21.0
# 5           1            python   2499        25.0
# 6           1            python   2499        12.0
# 7           1            python   2499        14.0
# 8           1            python   2499        38.0
# 9           2               sql   3499        19.0
# 10          2               sql   3499         7.0
# 11          3     data analysis   4999        22.0
# 12          3     data analysis   4999        13.0
# 13          3     data analysis   4999        23.0
# 14          3     data analysis   4999         3.0
# 15          3     data analysis   4999        16.0
# 16          4  machine learning   9999        23.0
# 17          4  machine learning   9999        19.0
# 18          4  machine learning   9999        24.0
# 19          4  machine learning   9999        14.0
# 20          5           tableau   2499        15.0
# 21          5           tableau   2499        16.0
# 22          5           tableau   2499         3.0
# 23          5           tableau   2499        12.0
# 24          5           tableau   2499         2.0
# 25          5           tableau   2499        22.0
# 26          5           tableau   2499        23.0
# 27          6          power bi   1899        18.0
# 28          6          power bi   1899         1.0
# 29          6          power bi   1899        23.0
# 30          6          power bi   1899        14.0
# 31          6          power bi   1899         7.0
# 32          6          power bi   1899        22.0
# 33          7          ms sxcel   1599        11.0
# 34          7          ms sxcel   1599        17.0
# 35          7          ms sxcel   1599        16.0
# 36          7          ms sxcel   1599         7.0
# 37          7          ms sxcel   1599        12.0
# 38          8            pandas   1099         7.0
# 39          8            pandas   1099        11.0
# 40          8            pandas   1099        18.0
# 41          8            pandas   1099        50.0
# 42          9            plotly    699        16.0
# 43          9            plotly    699        14.0
# 44          9            plotly    699         1.0
# 45          9            plotly    699        23.0
# 46          9            plotly    699        42.0
# 47         10           pyspark   2499         7.0
# 48         10           pyspark   2499        25.0
# 49         10           pyspark   2499        12.0
# 50         10           pyspark   2499        17.0
# 51         10           pyspark   2499         1.0
# 52         10           pyspark   2499        11.0
# 53         11             Numpy    699         NaN
# 54         12               C++   1299         NaN

# %%
courses.merge(regs,how='right',on='course_id')
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499          23
# 1           5           tableau   2499          15
# 2           6          power bi   1899          18
# 3           4  machine learning   9999          23
# 4           9            plotly    699          16
# 5           1            python   2499          18
# 6           1            python   2499           1
# 7           8            pandas   1099           7
# 8           3     data analysis   4999          22
# 9           1            python   2499          15
# 10          4  machine learning   9999          19
# 11          6          power bi   1899           1
# 12         10           pyspark   2499           7
# 13          7          ms sxcel   1599          11
# 14          3     data analysis   4999          13
# 15          4  machine learning   9999          24
# 16          1            python   2499          21
# 17          5           tableau   2499          16
# 18          3     data analysis   4999          23
# 19          7          ms sxcel   1599          17
# 20          6          power bi   1899          23
# 21          1            python   2499          25
# 22          2               sql   3499          19
# 23         10           pyspark   2499          25
# 24          3     data analysis   4999           3
# 25          5           tableau   2499           3
# 26          7          ms sxcel   1599          16
# 27         10           pyspark   2499          12
# 28          1            python   2499          12
# 29          9            plotly    699          14
# 30          7          ms sxcel   1599           7
# 31          2               sql   3499           7
# 32          3     data analysis   4999          16
# 33         10           pyspark   2499          17
# 34          8            pandas   1099          11
# 35          6          power bi   1899          14
# 36          5           tableau   2499          12
# 37          7          ms sxcel   1599          12
# 38          8            pandas   1099          18
# 39         10           pyspark   2499           1
# 40          9            plotly    699           1
# 41          5           tableau   2499           2
# 42          6          power bi   1899           7
# 43          5           tableau   2499          22
# 44          6          power bi   1899          22
# 45          9            plotly    699          23
# 46          5           tableau   2499          23
# 47          4  machine learning   9999          14
# 48          1            python   2499          14
# 49         10           pyspark   2499          11
# 50          9            plotly    699          42
# 51          8            pandas   1099          50
# 52          1            python   2499          38

# %%
#in right join, everything of right df will show & vice versa for left join

# %%
#outer join
#full join will show all data from both table

students.merge(regs,how='outer',on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo     23.0        1.0
# 1            1       Kailash Harjo     23.0        6.0
# 2            1       Kailash Harjo     23.0       10.0
# 3            1       Kailash Harjo     23.0        9.0
# 4            2         Esha Butala      1.0        5.0
# 5            3      Parveen Bhalla      3.0        3.0
# 6            3      Parveen Bhalla      3.0        5.0
# 7            4         Marlo Dugal     14.0        NaN
# 8            5         Kusum Bahri      6.0        NaN
# 9            6  Lakshmi Contractor     10.0        NaN
# 10           7        Tarun Thaker      9.0        8.0
# 11           7        Tarun Thaker      9.0       10.0
# 12           7        Tarun Thaker      9.0        7.0
# 13           7        Tarun Thaker      9.0        2.0
# 14           7        Tarun Thaker      9.0        6.0
# 15           8      Radheshyam Dey      5.0        NaN
# 16           9   Nitika Chatterjee      4.0        NaN
# 17          10      Aayushman Sant      8.0        NaN
# 18          11  David Mukhopadhyay     20.0        7.0
# 19          11  David Mukhopadhyay     20.0        8.0
# 20          11  David Mukhopadhyay     20.0       10.0
# 21          12          Radha Dutt     19.0       10.0
# 22          12          Radha Dutt     19.0        1.0
# 23          12          Radha Dutt     19.0        5.0
# 24          12          Radha Dutt     19.0        7.0
# 25          13      Munni Varghese     24.0        3.0
# 26          14    Pranab Natarajan     22.0        9.0
# 27          14    Pranab Natarajan     22.0        6.0
# 28          14    Pranab Natarajan     22.0        4.0
# 29          14    Pranab Natarajan     22.0        1.0
# 30          15           Preet Sha     16.0        5.0
# 31          15           Preet Sha     16.0        1.0
# 32          16        Elias Dodiya     25.0        9.0
# 33          16        Elias Dodiya     25.0        5.0
# 34          16        Elias Dodiya     25.0        7.0
# 35          16        Elias Dodiya     25.0        3.0
# 36          17        Yasmin Palan      7.0        7.0
# 37          17        Yasmin Palan      7.0       10.0
# 38          18     Fardeen Mahabir     13.0        6.0
# 39          18     Fardeen Mahabir     13.0        1.0
# 40          18     Fardeen Mahabir     13.0        8.0
# 41          19        Qabeel Raman     12.0        4.0
# 42          19        Qabeel Raman     12.0        2.0
# 43          20       Hanuman Hegde     11.0        NaN
# 44          21          Seema Kota     15.0        1.0
# 45          22          Yash Sethi     21.0        3.0
# 46          22          Yash Sethi     21.0        5.0
# 47          22          Yash Sethi     21.0        6.0
# 48          23      Chhavi Lachman     18.0        1.0
# 49          23      Chhavi Lachman     18.0        4.0
# 50          23      Chhavi Lachman     18.0        3.0
# 51          23      Chhavi Lachman     18.0        6.0
# 52          23      Chhavi Lachman     18.0        9.0
# 53          23      Chhavi Lachman     18.0        5.0
# 54          24        Radhika Suri     17.0        4.0
# 55          25     Shashank DAlia      2.0        1.0
# 56          25     Shashank DAlia      2.0       10.0
# 57          42                 NaN      NaN        9.0
# 58          50                 NaN      NaN        8.0
# 59          38                 NaN      NaN        1.0

# %% [markdown]
# ## Practice

# %%
#find total revenue generated

regs.merge(courses,how='inner',on='course_id')    #inner join bcoz we need only those value which are present in both table
# Out:
#     student_id  course_id       course_name  price
# 0           23          1            python   2499
# 1           18          1            python   2499
# 2            1          1            python   2499
# 3           15          1            python   2499
# 4           21          1            python   2499
# 5           25          1            python   2499
# 6           12          1            python   2499
# 7           14          1            python   2499
# 8           38          1            python   2499
# 9           15          5           tableau   2499
# 10          16          5           tableau   2499
# 11           3          5           tableau   2499
# 12          12          5           tableau   2499
# 13           2          5           tableau   2499
# 14          22          5           tableau   2499
# 15          23          5           tableau   2499
# 16          18          6          power bi   1899
# 17           1          6          power bi   1899
# 18          23          6          power bi   1899
# 19          14          6          power bi   1899
# 20           7          6          power bi   1899
# 21          22          6          power bi   1899
# 22          23          4  machine learning   9999
# 23          19          4  machine learning   9999
# 24          24          4  machine learning   9999
# 25          14          4  machine learning   9999
# 26          16          9            plotly    699
# 27          14          9            plotly    699
# 28           1          9            plotly    699
# 29          23          9            plotly    699
# 30          42          9            plotly    699
# 31           7          8            pandas   1099
# 32          11          8            pandas   1099
# 33          18          8            pandas   1099
# 34          50          8            pandas   1099
# 35          22          3     data analysis   4999
# 36          13          3     data analysis   4999
# 37          23          3     data analysis   4999
# 38           3          3     data analysis   4999
# 39          16          3     data analysis   4999
# 40           7         10           pyspark   2499
# 41          25         10           pyspark   2499
# 42          12         10           pyspark   2499
# 43          17         10           pyspark   2499
# 44           1         10           pyspark   2499
# 45          11         10           pyspark   2499
# 46          11          7          ms sxcel   1599
# 47          17          7          ms sxcel   1599
# 48          16          7          ms sxcel   1599
# 49           7          7          ms sxcel   1599
# 50          12          7          ms sxcel   1599
# 51          19          2               sql   3499
# 52           7          2               sql   3499

# %%
regs.merge(courses,how='inner',on='course_id')['price'].sum()
# Out:
# 154247

# %%
#find month by month revenue

temp_df = pd.concat([nov,dec],keys=["Nov","Dec"]).reset_index()
temp_df = temp_df.merge(courses,on='course_id')
temp_df.groupby('level_0')['price'].sum()
# Out:
# level_0
# Dec    65072
# Nov    89175
# Name: price, dtype: int64

# %%
#make a registration table
# std name, course name, price

#regs
#students
#courses

regs.merge(students,on='student_id').merge(courses,on='course_id')[['name','course_name','price']]
# Out:
#                   name       course_name  price
# 0       Chhavi Lachman            python   2499
# 1            Preet Sha            python   2499
# 2      Fardeen Mahabir            python   2499
# 3        Kailash Harjo            python   2499
# 4           Seema Kota            python   2499
# 5      Shashank DAlia            python   2499
# 6           Radha Dutt            python   2499
# 7     Pranab Natarajan            python   2499
# 8       Chhavi Lachman  machine learning   9999
# 9         Qabeel Raman  machine learning   9999
# 10        Radhika Suri  machine learning   9999
# 11    Pranab Natarajan  machine learning   9999
# 12      Chhavi Lachman     data analysis   4999
# 13        Elias Dodiya     data analysis   4999
# 14          Yash Sethi     data analysis   4999
# 15      Munni Varghese     data analysis   4999
# 16      Parveen Bhalla     data analysis   4999
# 17      Chhavi Lachman          power bi   1899
# 18     Fardeen Mahabir          power bi   1899
# 19       Kailash Harjo          power bi   1899
# 20        Tarun Thaker          power bi   1899
# 21          Yash Sethi          power bi   1899
# 22    Pranab Natarajan          power bi   1899
# 23      Chhavi Lachman            plotly    699
# 24        Elias Dodiya            plotly    699
# 25       Kailash Harjo            plotly    699
# 26    Pranab Natarajan            plotly    699
# 27      Chhavi Lachman           tableau   2499
# 28           Preet Sha           tableau   2499
# 29        Elias Dodiya           tableau   2499
# 30          Yash Sethi           tableau   2499
# 31      Parveen Bhalla           tableau   2499
# 32          Radha Dutt           tableau   2499
# 33         Esha Butala           tableau   2499
# 34     Fardeen Mahabir            pandas   1099
# 35        Tarun Thaker            pandas   1099
# 36  David Mukhopadhyay            pandas   1099
# 37        Elias Dodiya          ms sxcel   1599
# 38        Tarun Thaker          ms sxcel   1599
# 39  David Mukhopadhyay          ms sxcel   1599
# 40        Yasmin Palan          ms sxcel   1599
# 41          Radha Dutt          ms sxcel   1599
# 42       Kailash Harjo           pyspark   2499
# 43        Tarun Thaker           pyspark   2499
# 44  David Mukhopadhyay           pyspark   2499
# 45        Yasmin Palan           pyspark   2499
# 46     Shashank DAlia           pyspark   2499
# 47          Radha Dutt           pyspark   2499
# 48        Tarun Thaker               sql   3499
# 49        Qabeel Raman               sql   3499

# %%
#plot bar chart for revenue/courses

regs.merge(courses,on='course_id').groupby('course_name')['price'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='course_name'>

# %%
#find students who enrolled in both months

common_id = np.intersect1d(nov['student_id'],dec['student_id'])
common_id
# Out:
# array([ 1,  3,  7, 11, 16, 17, 18, 22, 23])

# %%
students[students['student_id'].isin(common_id)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
#find students that got no enrollment

common = np.setdiff1d(courses['course_id'],regs['course_id'])
students[students['student_id'].isin(common)]
# Out:
#     student_id                name  partner
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19

# %%
#find students who never enrolled in any course

common = np.setdiff1d(students['student_id'],regs['student_id'])
students[students['student_id'].isin(common)].shape[0]
# Out:
# 7

# %%
#print student name --> partner name -- for all who enrolled
#self join

students.merge(students,left_on='partner',right_on='student_id').merge(regs,left_on ='student_id_x',right_on='student_id').merge(courses,on='course_id')[['name_x','name_y','course_name','price']]
# Out:
#                 name_x             name_y       course_name  price
# 0        Kailash Harjo     Chhavi Lachman            python   2499
# 1           Radha Dutt       Qabeel Raman            python   2499
# 2     Pranab Natarajan         Yash Sethi            python   2499
# 3            Preet Sha       Elias Dodiya            python   2499
# 4      Fardeen Mahabir     Munni Varghese            python   2499
# 5           Seema Kota          Preet Sha            python   2499
# 6       Chhavi Lachman    Fardeen Mahabir            python   2499
# 7      Shashank DAlia        Esha Butala            python   2499
# 8        Kailash Harjo     Chhavi Lachman          power bi   1899
# 9         Tarun Thaker  Nitika Chatterjee          power bi   1899
# 10    Pranab Natarajan         Yash Sethi          power bi   1899
# 11     Fardeen Mahabir     Munni Varghese          power bi   1899
# 12          Yash Sethi         Seema Kota          power bi   1899
# 13      Chhavi Lachman    Fardeen Mahabir          power bi   1899
# 14       Kailash Harjo     Chhavi Lachman           pyspark   2499
# 15        Tarun Thaker  Nitika Chatterjee           pyspark   2499
# 16  David Mukhopadhyay      Hanuman Hegde           pyspark   2499
# 17          Radha Dutt       Qabeel Raman           pyspark   2499
# 18        Yasmin Palan       Tarun Thaker           pyspark   2499
# 19     Shashank DAlia        Esha Butala           pyspark   2499
# 20       Kailash Harjo     Chhavi Lachman            plotly    699
# 21    Pranab Natarajan         Yash Sethi            plotly    699
# 22        Elias Dodiya    Shashank DAlia            plotly    699
# 23      Chhavi Lachman    Fardeen Mahabir            plotly    699
# 24         Esha Butala      Kailash Harjo           tableau   2499
# 25      Parveen Bhalla     Parveen Bhalla           tableau   2499
# 26          Radha Dutt       Qabeel Raman           tableau   2499
# 27           Preet Sha       Elias Dodiya           tableau   2499
# 28        Elias Dodiya    Shashank DAlia           tableau   2499
# 29          Yash Sethi         Seema Kota           tableau   2499
# 30      Chhavi Lachman    Fardeen Mahabir           tableau   2499
# 31      Parveen Bhalla     Parveen Bhalla     data analysis   4999
# 32      Munni Varghese       Radhika Suri     data analysis   4999
# 33        Elias Dodiya    Shashank DAlia     data analysis   4999
# 34          Yash Sethi         Seema Kota     data analysis   4999
# 35      Chhavi Lachman    Fardeen Mahabir     data analysis   4999
# 36        Tarun Thaker  Nitika Chatterjee            pandas   1099
# 37  David Mukhopadhyay      Hanuman Hegde            pandas   1099
# 38     Fardeen Mahabir     Munni Varghese            pandas   1099
# 39        Tarun Thaker  Nitika Chatterjee          ms sxcel   1599
# 40  David Mukhopadhyay      Hanuman Hegde          ms sxcel   1599
# 41          Radha Dutt       Qabeel Raman          ms sxcel   1599
# 42        Elias Dodiya    Shashank DAlia          ms sxcel   1599
# 43        Yasmin Palan       Tarun Thaker          ms sxcel   1599
# 44        Tarun Thaker  Nitika Chatterjee               sql   3499
# 45        Qabeel Raman         Radha Dutt               sql   3499
# 46    Pranab Natarajan         Yash Sethi  machine learning   9999
# 47        Qabeel Raman         Radha Dutt  machine learning   9999
# 48      Chhavi Lachman    Fardeen Mahabir  machine learning   9999
# 49        Radhika Suri       Yasmin Palan  machine learning   9999

# %%
#find top3 students who did most number of enrollment
regs.merge(students,on='student_id').groupby(['student_id','name'])['course_id'].count().nlargest()
# Out:
# student_id  name
# 23          Chhavi Lachman      6
# 7           Tarun Thaker        5
# 1           Kailash Harjo       4
# 12          Radha Dutt          4
# 14          Pranab Natarajan    4
# Name: course_id, dtype: int64

# %%
#find top 3 students who spent most amount of money on courses

regs.merge(courses,on='course_id').merge(students,on='student_id').groupby(['student_id','name']).sum().reset_index()[['name','price']].sort_values(by='price',ascending=False).head()
# Out:
# <ipython-input-40-39c6385fe914>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   regs.merge(courses,on='course_id').merge(students,on='student_id').groupby(['student_id','name']).sum().reset_index()[['name','price']].sort_values(by='price',ascending=False).head()
#                 name  price
# 15    Chhavi Lachman  22594
# 7   Pranab Natarajan  15096
# 12      Qabeel Raman  13498
# 3       Tarun Thaker  10595
# 16      Radhika Suri   9999

# %% [markdown]
# ## Alternate syntax of merge

# %%
pd.merge(students,regs,how='inner',on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23          1
# 1            1       Kailash Harjo       23          6
# 2            1       Kailash Harjo       23         10
# 3            1       Kailash Harjo       23          9
# 4            2         Esha Butala        1          5
# 5            3      Parveen Bhalla        3          3
# 6            3      Parveen Bhalla        3          5
# 7            7        Tarun Thaker        9          8
# 8            7        Tarun Thaker        9         10
# 9            7        Tarun Thaker        9          7
# 10           7        Tarun Thaker        9          2
# 11           7        Tarun Thaker        9          6
# 12          11  David Mukhopadhyay       20          7
# 13          11  David Mukhopadhyay       20          8
# 14          11  David Mukhopadhyay       20         10
# 15          12          Radha Dutt       19         10
# 16          12          Radha Dutt       19          1
# 17          12          Radha Dutt       19          5
# 18          12          Radha Dutt       19          7
# 19          13      Munni Varghese       24          3
# 20          14    Pranab Natarajan       22          9
# 21          14    Pranab Natarajan       22          6
# 22          14    Pranab Natarajan       22          4
# 23          14    Pranab Natarajan       22          1
# 24          15           Preet Sha       16          5
# 25          15           Preet Sha       16          1
# 26          16        Elias Dodiya       25          9
# 27          16        Elias Dodiya       25          5
# 28          16        Elias Dodiya       25          7
# 29          16        Elias Dodiya       25          3
# 30          17        Yasmin Palan        7          7
# 31          17        Yasmin Palan        7         10
# 32          18     Fardeen Mahabir       13          6
# 33          18     Fardeen Mahabir       13          1
# 34          18     Fardeen Mahabir       13          8
# 35          19        Qabeel Raman       12          4
# 36          19        Qabeel Raman       12          2
# 37          21          Seema Kota       15          1
# 38          22          Yash Sethi       21          3
# 39          22          Yash Sethi       21          5
# 40          22          Yash Sethi       21          6
# 41          23      Chhavi Lachman       18          1
# 42          23      Chhavi Lachman       18          4
# 43          23      Chhavi Lachman       18          3
# 44          23      Chhavi Lachman       18          6
# 45          23      Chhavi Lachman       18          9
# 46          23      Chhavi Lachman       18          5
# 47          24        Radhika Suri       17          4
# 48          25     Shashank DAlia        2          1
# 49          25     Shashank DAlia        2         10

# %% [markdown]
# ## Practice on IPL Dataset

# %%
#find top 3 stadiums with highest sixes/match ratio


temp_df = delivery.merge(matches,left_on='match_id',right_on='id')
six_df = temp_df[temp_df['batsman_runs'] == 6]
six_df
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 10             1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 47             1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 75             1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 89             1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 91             1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 122708       517       2  Kolkata Knight Riders              Kings XI Punjab
# 122738       518       1         Mumbai Indians        Kolkata Knight Riders
# 122801       518       1         Mumbai Indians        Kolkata Knight Riders
# 122813       518       1         Mumbai Indians        Kolkata Knight Riders
# 122822       518       1         Mumbai Indians        Kolkata Knight Riders
#
#         over  ball       batsman   non_striker           bowler  \
# 10         2     4     DA Warner      S Dhawan      A Choudhary
# 47         8     4  MC Henriques      S Dhawan          TM Head
# 75        13     2  Yuvraj Singh  MC Henriques      A Choudhary
# 89        15     3  Yuvraj Singh  MC Henriques        S Aravind
# 91        15     5  MC Henriques  Yuvraj Singh        S Aravind
# ...      ...   ...           ...           ...              ...
# 122708    19     6     PP Chawla     SP Narine       MG Johnson
# 122738     5     3     RG Sharma       AP Tare  Shakib Al Hasan
# 122801    15     5     RG Sharma   CJ Anderson         UT Yadav
# 122813    17     5     RG Sharma   CJ Anderson        SP Narine
# 122822    19     1   CJ Anderson     RG Sharma       AD Russell
#
#         is_super_over  ...  result  dl_applied                 winner  \
# 10                0.0  ...  normal           0    Sunrisers Hyderabad
# 47                0.0  ...  normal           0    Sunrisers Hyderabad
# 75                0.0  ...  normal           0    Sunrisers Hyderabad
# 89                0.0  ...  normal           0    Sunrisers Hyderabad
# 91                0.0  ...  normal           0    Sunrisers Hyderabad
# ...               ...  ...     ...         ...                    ...
# 122708            0.0  ...  normal           0  Kolkata Knight Riders
# 122738            0.0  ...  normal           0  Kolkata Knight Riders
# 122801            0.0  ...  normal           0  Kolkata Knight Riders
# 122813            0.0  ...  normal           0  Kolkata Knight Riders
# 122822            0.0  ...  normal           0  Kolkata Knight Riders
#
#         win_by_runs  win_by_wickets  player_of_match  \
# 10               35               0     Yuvraj Singh
# 47               35               0     Yuvraj Singh
# 75               35               0     Yuvraj Singh
# 89               35               0     Yuvraj Singh
# 91               35               0     Yuvraj Singh
# ...             ...             ...              ...
# 122708            0               3        MK Pandey
# 122738            0               7         M Morkel
# 122801            0               7         M Morkel
# 122813            0               7         M Morkel
# 122822            0               7         M Morkel
#
#                                             venue          umpire1  \
# 10      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# 47      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# 75      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# 89      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# 91      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# ...                                           ...              ...
# 122708                      M Chinnaswamy Stadium  HDPK Dharmasena
# 122738                               Eden Gardens           S Ravi
# 122801                               Eden Gardens           S Ravi
# 122813                               Eden Gardens           S Ravi
# 122822                               Eden Gardens           S Ravi
#
#               umpire2 umpire3
# 10           NJ Llong     NaN
# 47           NJ Llong     NaN
# 75           NJ Llong     NaN
# 89           NJ Llong     NaN
# 91           NJ Llong     NaN
# ...               ...     ...
# 122708   BNJ Oxenford     NaN
# 122738  C Shamshuddin     NaN
# 122801  C Shamshuddin     NaN
# 122813  C Shamshuddin     NaN
# 122822  C Shamshuddin     NaN
#
# [5196 rows x 39 columns]

# %%
num_six = six_df.groupby('venue')['venue'].count()

# %%
num_match = matches['venue'].value_counts()
num_match
# Out:
# M Chinnaswamy Stadium                                   66
# Eden Gardens                                            61
# Feroz Shah Kotla                                        60
# Wankhede Stadium                                        57
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Maharashtra Cricket Association Stadium                 15
# Kingsmead                                               15
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Punjab Cricket Association IS Bindra Stadium, Mohali    11
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# Brabourne Stadium                                       11
# Saurashtra Cricket Association Stadium                  10
# Himachal Pradesh Cricket Association Stadium             9
# New Wanderers Stadium                                    8
# Newlands                                                 7
# St George's Park                                         7
# Sheikh Zayed Stadium                                     7
# JSCA International Stadium Complex                       7
# Barabati Stadium                                         7
# Dubai International Cricket Stadium                      7
# Shaheed Veer Narayan Singh International Stadium         6
# Sharjah Cricket Stadium                                  6
# Holkar Cricket Stadium                                   5
# Nehru Stadium                                            5
# Green Park                                               4
# Vidarbha Cricket Association Stadium, Jamtha             3
# De Beers Diamond Oval                                    3
# Buffalo Park                                             3
# OUTsurance Oval                                          2
# Name: venue, dtype: int64

# %%
(num_six/num_match).nlargest()
# Out:
# Holkar Cricket Stadium                          17.600000
# Sharjah Cricket Stadium                         12.666667
# Himachal Pradesh Cricket Association Stadium    12.000000
# De Beers Diamond Oval                           11.333333
# Dr DY Patil Sports Academy                      10.176471
# Name: venue, dtype: float64

# %%
#find orange cap holder of all season

matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
matches.merge(delivery,left_on='id',right_on='match_id').groupby(['season','batsman'])['batsman_runs'].sum().reset_index().sort_values(by='batsman_runs',ascending=False).drop_duplicates(subset=['season'])
# Out:
#       season       batsman  batsman_runs
# 910     2013    MEK Hussey         733.0
# 684     2012      CH Gayle         733.0
# 1088    2014    RV Uthappa         660.0
# 1162    2017     DA Warner         641.0
# 446     2010  SR Tendulkar         618.0
# 115     2008      SE Marsh         616.0
# 502     2011      CH Gayle         608.0
# 229     2009     ML Hayden         572.0
# 1127    2015     RG Sharma          86.0

# %% [markdown]
# ## Task

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# DATA DESCRIPTION
# ```
# file name -> Columns
# quater-i.csv -> ['order_id', 'quantity', 'item_id', 'choice_description_id' 'item_price']
# items.csv -> ['item_id', 'item_name']
# ```
# Dataset Link - https://drive.google.com/drive/folders/1Z0kaFybvgFeczeUj4dldUnhTdloLqLsL?usp=share_link

# %%
items_path = pd.read_csv('/content/items.csv')
q1 = pd.read_csv('/content/quarter-1.csv')
q2 = pd.read_csv('/content/quarter-2.csv')
q3 = pd.read_csv('/content/quarter-3.csv')

# %% [markdown]
# ###`Q:1-5`
# 1. You are given three quater files, your job is to append these three files and make a single dataframe.
# 2. Have a index as Q-1 Q-2 Q-3 for respective quater files in the dataframe
# 3. Your are given a file items.csv which has item_id and item_name. Find out most sold items in each quarter.
# 4. Find out items which has made most revenue in each quarter.
# 5. Find out avg order price of each quarter.
#
# ***Note: item_price is given as str with $ sign, in earlier task you have converted this to rupees, here too first convert item_price field in rupees.***

# %%
df = pd.concat([q1,q2,q3],keys=['q1','q2','q3'])
df.reset_index().merge(items_path,on='item_id').groupby(['item_name','level_0'])['item_id'].count().nlargest().reset_index().drop_duplicates(subset='level_0')
# Out:
#       item_name level_0  item_id
# 0  Chicken Bowl      q2      375
# 1  Chicken Bowl      q1      351

# %%
df = pd.concat([q1,q2,q3],keys=['q1','q2','q3'])
df['item_price'] = df['item_price'].apply(lambda x:x[1:]).astype('float')
df.reset_index().merge(items_path,on='item_id').groupby(['item_name','level_0'])['item_price'].sum().reset_index().drop_duplicates(subset='level_0',keep='first')
# Out:
#            item_name level_0  item_price
# 0  6 Pack Soft Drink      q1      201.19
# 1  6 Pack Soft Drink      q2      155.76

# %% [markdown]
# ###`Q-6` From the IPL wala dataset you have to find the Purple cap holder each season.
#
# *Note: Bowler with most no wickets in a season gets purple cap. If more than one bowler have same no of wickets in the season, one with least ecomnomy among them is purple cap holder.*
#
# Bowler's Economy = runs-conceded per six balls

# %%
import pandas as pd
import numpy as np

balls = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022.csv')
matches = pd.read_csv('/content/IPL_Matches_2008_2022.csv')

# %%
season_df = balls.merge(matches[['ID','Season']],on=["ID"])
season_df
# Out:
#              ID  innings  overs  ballnumber         batter          bowler  \
# 0       1312200        1      0           1    YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2    YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3     JC Buttler  Mohammed Shami
# 3       1312200        1      0           4    YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5    YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...            ...             ...
# 213748   336035        1     14           4  KC Sangakkara        Umar Gul
# 213749   336035        1     14           5  KC Sangakkara        Umar Gul
# 213750   336035        1     14           6  KC Sangakkara        Umar Gul
# 213751   336035        1     15           1   Yuvraj Singh        I Sharma
# 213752   336035        1     15           2   Yuvraj Singh             NaN
#
#              non-striker extra_type  batsman_run  extras_run  total_run  \
# 0             JC Buttler        NaN          0.0         0.0        0.0
# 1             JC Buttler    legbyes          0.0         1.0        1.0
# 2            YBK Jaiswal        NaN          1.0         0.0        1.0
# 3             JC Buttler        NaN          0.0         0.0        0.0
# 4             JC Buttler        NaN          0.0         0.0        0.0
# ...                  ...        ...          ...         ...        ...
# 213748      Yuvraj Singh        NaN          6.0         0.0        6.0
# 213749      Yuvraj Singh        NaN          2.0         0.0        2.0
# 213750      Yuvraj Singh        NaN          0.0         0.0        0.0
# 213751  DPMD Jayawardene        NaN          0.0         0.0        0.0
# 213752               NaN        NaN          NaN         NaN        NaN
#
#         non_boundary  isWicketDelivery     player_out kind fielders_involved  \
# 0                0.0               0.0            NaN  NaN               NaN
# 1                0.0               0.0            NaN  NaN               NaN
# 2                0.0               0.0            NaN  NaN               NaN
# 3                0.0               0.0            NaN  NaN               NaN
# 4                0.0               0.0            NaN  NaN               NaN
# ...              ...               ...            ...  ...               ...
# 213748           0.0               0.0            NaN  NaN               NaN
# 213749           0.0               0.0            NaN  NaN               NaN
# 213750           0.0               1.0  KC Sangakkara  lbw               NaN
# 213751           0.0               0.0            NaN  NaN               NaN
# 213752           NaN               NaN            NaN  NaN               NaN
#
#              BattingTeam   Season
# 0       Rajasthan Royals     2022
# 1       Rajasthan Royals     2022
# 2       Rajasthan Royals     2022
# 3       Rajasthan Royals     2022
# 4       Rajasthan Royals     2022
# ...                  ...      ...
# 213748   Kings XI Punjab  2007/08
# 213749   Kings XI Punjab  2007/08
# 213750   Kings XI Punjab  2007/08
# 213751   Kings XI Punjab  2007/08
# 213752               NaN  2007/08
#
# [213753 rows x 18 columns]

# %%
kind_lis = balls['kind'].unique().tolist()
kind_lis

#all wickets will not be count for bowler so we need to filter
# Out:
# [nan,
#  'caught',
#  'caught and bowled',
#  'run out',
#  'bowled',
#  'stumped',
#  'lbw',
#  'hit wicket',
#  'retired hurt',
#  'retired out',
#  'obstructing the field']

# %%
 season_df['isbowlerwicket'] = season_df['kind'].apply(lambda x:1 if x in ['caught',
 'caught and bowled',
 'bowled',
 'stumped',
 'lbw',
 'hit wicket'] else 0)

# %%
#each run doesnt count inder bowler

season_df['extra_type'].unique().tolist()
# Out:
# [nan, 'legbyes', 'wides', 'byes', 'noballs', 'penalty']

# %%
seasondf = balls.merge(matches[["ID", "Season"]], on="ID")
seasondf["IsBowlerWicket"] = seasondf.kind.apply(lambda x: 1 if x in ["caught", 'caught and bowled', 'bowled', 'stumped','lbw', 'hit wicket'] else 0)
seasondf["BowlerRun"] = seasondf.extra_type.apply(lambda x: 0 if x in ["legbyes", "byes"] else 1) * seasondf["total_run"]
seasondf["IsLegalBall"] = seasondf.extra_type.apply(lambda x: 0 if x in ["wides", "noballs"] else 1)
pcapdf = seasondf.groupby(["Season", "bowler"], as_index = False)[["IsBowlerWicket", "BowlerRun", "IsLegalBall"]].sum()
pcapdf["Economy"] = pcapdf["BowlerRun"] / pcapdf["IsLegalBall"] * 6
pcapdf.sort_values(["IsBowlerWicket", "Economy"], ascending = [False, True]).drop_duplicates("Season", keep = "first").sort_values("Season")
# Out:
#        Season       bowler  IsBowlerWicket  BowlerRun  IsLegalBall   Economy
# 12    2007/08    JA Morkel               6       89.0           72  7.416667
# 119      2009     RP Singh              23      417.0          358  6.988827
# 229   2009/10      PP Ojha              21      429.0          353  7.291785
# 392      2011   SL Malinga              28      375.0          378  5.952381
# 482      2012     M Morkel              25      453.0          378  7.190476
# 574      2013     DJ Bravo              32      497.0          375  7.952000
# 724      2014    MM Sharma              23      452.0          323  8.396285
# 792      2015     DJ Bravo              26      426.0          314  8.140127
# 883      2016      B Kumar              23      490.0          396  7.424242
# 993      2017      B Kumar              26      369.0          314  7.050955
# 1089     2018       AJ Tye              24      448.0          336  8.000000
# 1214     2019  Imran Tahir              26      431.0          386  6.699482
# 1326  2020/21     K Rabada              32      549.0          398  8.276382
# 1412     2021     HV Patel              32      459.0          338  8.147929
# 1616     2022    YS Chahal              27      527.0          408  7.750000

# %% [markdown]
# ###`Q-7:` Best bowler in death overs.
# *Note: Have taken most no of wickets in case of tie with least economy*
#
# Death Overs - [16-20]

# %%
death_overs = seasondf[seasondf['overs'] >= 15]
pcapdf = death_overs.groupby("bowler", as_index = False)[["IsBowlerWicket", "BowlerRun", "IsLegalBall"]].sum()
pcapdf['economy'] = pcapdf["BowlerRun"] / pcapdf["IsLegalBall"] * 6
pcapdf.sort_values(["IsBowlerWicket", "economy"], ascending = [False, True]).head()
# Out:
#          bowler  IsBowlerWicket  BowlerRun  IsLegalBall   economy
# 85     DJ Bravo             110     2077.0         1335  9.334831
# 317  SL Malinga             108     1464.0         1117  7.863921
# 50      B Kumar              90     1752.0         1173  8.961637
# 140   JJ Bumrah              80     1614.0         1146  8.450262
# 324   SP Narine              67     1164.0          949  7.359326

# %% [markdown]
# ###`Q-8` Batsman record season wise
#
# Make a function which takes a input `batsman_name` and it returns a dataframe.
# Columns of the data frame are - `['Season','Innings', 'TotalRuns', 'Avg', 'HighestScore','StrikeRate']`.
# * In result make `Season` column as index.
#
# * Avg - total_runs/ no of time got out. - player_out column will help.
# * StrikeRate -(total_runs/ balls faced) * 100- wides are not included in batsman ball faced counts. No balls are included. -> Extra_type column will help
# * Batsman Can score runs on No Balls.
# * Batsman can get out on No Ball or Wides. And even while being on non-striker. Keep these things in mind before masking.

# %%
# code here
batterdf = seasondf.copy()
batterdf["IsBatsmanBall"] = batterdf["extra_type"].apply(lambda x: 1 if x != "wides" else 0)

def bat_record_season(batsman):
    bdf = batterdf[batterdf.batter == batsman].copy()
    bdf["IsBatsmanOut"] = bdf.batter == bdf.player_out
    df = bdf.groupby(["Season", "ID"], as_index = False)[["batsman_run", "IsBatsmanBall", "IsBatsmanOut"]].sum()
    innings = df.groupby("Season").ID.count()
    df = df.groupby("Season").agg(
    {
        "batsman_run":["sum", "max"],
        "IsBatsmanBall": "sum",
        "IsBatsmanOut": "sum"
    })
    df["Innings"]= innings
    df["TotalRuns"] = df[("batsman_run", "sum")]
    df["Avg"] = df["TotalRuns"] / df[("IsBatsmanOut", "sum")]
    df["HighestScore"] = df[("batsman_run", "max")]
    df["StrikeRate"] = df["TotalRuns"] / df[("IsBatsmanBall", "sum")] * 100
    return df.drop(columns = ["batsman_run", "IsBatsmanBall", "IsBatsmanOut"])
bat_record_season("V Kohli")
# Out:
#         Innings TotalRuns        Avg HighestScore  StrikeRate
#
# Season
# 2009         13     246.0  22.363636         50.0  112.328767
# 2009/10      13     307.0  27.909091         58.0  144.811321
# 2011         16     557.0  46.416667         71.0  121.086957
# 2012         15     364.0  30.333333         73.0  111.656442
# 2013         16     639.0  45.642857         99.0  139.215686
# 2014         14     359.0  27.615385         73.0  122.108844
# 2015         16     505.0  45.909091         82.0  130.829016
# 2016         16     973.0  81.083333        113.0  152.031250
# 2017         10     308.0  30.800000         64.0  122.222222
# 2018         14     530.0  48.181818         92.0  139.107612
# 2019         14     464.0  33.142857        100.0  141.463415
# 2020/21      15     471.0  42.818182         90.0  122.020725
# 2021         15     405.0  28.928571         72.0  119.469027
# 2022         16     341.0  24.357143         73.0  115.986395

# %% [markdown]
# ###`Q-9` Using both dataset, make a dataframe as described below
#
# Data Frame columns-> `['PlayerOfThematch', 'BattingFigure', 'BowlingFigure']`
#
# * BattingFigure->`<runs>/<balls>`
# * BowlingFigure->`<wicket>/<runs-conceded>`
#
# DataFrame should have one record for each match.
#
# Say 'V Kohli' got POM award then in dataset include his batting figure of that match. Say he scored 112runs in 76 balls. And he hasn't bowled so Bowling Figure will be NaN
# ```
# PlayerOfThematch BattingFigure BowlingFigure
# V Kohli          112/76         nan
#
# ```

# %%
df = balls.merge(matches[['ID','Player_of_Match']],on='ID')
batter = df[df['batter'] == df['Player_of_Match']]

# %% [markdown]
# ## **Questions Based on Iris Dataset**
#
# - **Sepal All:** https://docs.google.com/spreadsheets/d/e/2PACX-1vT58ekmHTwptX7Bs4QOy6YByA1HMvYTACeeIjrKhHE0Pg1K_3egewHMKMh02zN9D5-yHVXfvuaa3s5u/pub?gid=2028782809&single=true&output=csv
#     - **Unnamed: 0:** Unused column. This column is created when creating this sub-dataset.
#     - **Id:** Id of the records.
#     - **SepalLengthCm:** Sepal length of flowers in cm
#     - **SepalWidthCm:** Sepal width of flowers in cm
#
# - **Petal All:** https://docs.google.com/spreadsheets/d/e/2PACX-1vQinLXShrOz4ExNaW1bSQVuvbbhIzJW7G0kkkD2SvqSD6STjLrQQiftgI7BGe10sBZi0CNr2_sJpQAz/pub?gid=1580010789&single=true&output=csv
#     - **Unnamed: 0:** Unused column. This column is created when creating this sub-dataset.
#     - **Id:** Id of the records.
#     - **PetalLengthCm:** Petal length of flowers in cm
#     - **PetalWidthCm:** Petal width of flowers in cm
#
# - **Iris Virginica:** https://docs.google.com/spreadsheets/d/e/2PACX-1vSK39MwduGPHYNgw5yViezoLYCVDKMCWIHzjnt3GZNaxHPFOQLr2q6no_tyqTsOk-VfXleslfGVe9eJ/pub?gid=314231613&single=true&output=csv
#     - **Unnamed: 0:** Unused column. This column is created when creating the sub-dataset.
#     - **Id:** Id of the records.
#     - **Species:** Name of this species.
#
# - **Iris Versicolor:** https://docs.google.com/spreadsheets/d/e/2PACX-1vTcSFgLnabqIrgIc5WlwvnbbvyyJsgZjR-0E0-4TR-5aHgv_0EP6yNWglkkls3AXM2qHCR5VYzWCoTM/pub?gid=715607857&single=true&output=csv
#     - **Unnamed: 0:** Unused column. This column is created when creating the sub-dataset.
#     - **Id:** Id of the records.
#     - **Species:** Name of this species.
#
# - **Iris Setosa:** https://docs.google.com/spreadsheets/d/e/2PACX-1vSjqJpdgy2X_oDUUqQ0sSaFKqnnf8MYU4KgJSYgHaHmq0Wb1weMOsJXh-rICHmkLcaTkOwzMYLeh959/pub?gid=2003684803&single=true&output=csv
#     - **Unnamed 0:** Unused column. This column is created when creating the sub-dataset.
#     - **Id:** Id of the records.
#     - **Species:** Name of this species.

# %%
import pandas as pd
sepal_all = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT58ekmHTwptX7Bs4QOy6YByA1HMvYTACeeIjrKhHE0Pg1K_3egewHMKMh02zN9D5-yHVXfvuaa3s5u/pub?gid=2028782809&single=true&output=csv")
petal_all = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQinLXShrOz4ExNaW1bSQVuvbbhIzJW7G0kkkD2SvqSD6STjLrQQiftgI7BGe10sBZi0CNr2_sJpQAz/pub?gid=1580010789&single=true&output=csv")
virginica = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSK39MwduGPHYNgw5yViezoLYCVDKMCWIHzjnt3GZNaxHPFOQLr2q6no_tyqTsOk-VfXleslfGVe9eJ/pub?gid=314231613&single=true&output=csv")
versicolor = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTcSFgLnabqIrgIc5WlwvnbbvyyJsgZjR-0E0-4TR-5aHgv_0EP6yNWglkkls3AXM2qHCR5VYzWCoTM/pub?gid=715607857&single=true&output=csv")
setosa = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSjqJpdgy2X_oDUUqQ0sSaFKqnnf8MYU4KgJSYgHaHmq0Wb1weMOsJXh-rICHmkLcaTkOwzMYLeh959/pub?gid=2003684803&single=true&output=csv")

# %% [markdown]
# ### `Q-9:` Plot a bar chart of the average Sepal Length  of Virginica and average Petal length of Setosa flower.

# %%
sepal = pd.merge(virginica,sepal_all,on='Id')['SepalLengthCm'].mean()
petal = pd.merge(setosa,petal_all,on='Id')['PetalLengthCm'].mean()

pd.DataFrame({'kind':['Sepal Length','Petal Length'],"Length":[sepal,petal]}).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### `Q-10:` Create the complete dataset by uisng the below datasets:
# - virginica
# - versicolor
# - setosa
# - sepal all
# - petal all
#
# This dataset should have these below column names in order:
# 1. Id
# 2. Species
# 3. SepalLengthCm
# 4. SepalWidthCm
# 5. PetalLengthCm
# 6. PetalWidthCm
#
# Also, the dataset should be shuffled means the `Id` column should not be in increasing or decreasing order. So, make a dataset which has the shuffled Id column. You can use `DataFrame.sample()` method to shuffle.

# %%
vir = virginica.merge(sepal_all,on='Id').merge(petal_all,on = 'Id').drop(columns=['Unnamed: 0_x','Unnamed: 0_y','Unnamed: 0'])
ver = versicolor.merge(sepal_all,on='Id').merge(petal_all,on = 'Id').drop(columns=['Unnamed: 0_x','Unnamed: 0_y','Unnamed: 0'])
set = setosa.merge(sepal_all,on='Id').merge(petal_all,on = 'Id').drop(columns=['Unnamed: 0_x','Unnamed: 0_y','Unnamed: 0'])


new_dataset = pd.concat([vir,ver,set]).sample(150)
new_dataset
# Out:
#      Id          Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 4    55  Iris-versicolor            6.5           2.8            4.6
# 8   109   Iris-virginica            6.7           2.5            5.8
# 38   89  Iris-versicolor            5.6           3.0            4.1
# 43   94  Iris-versicolor            5.0           2.3            3.3
# 14   15      Iris-setosa            5.8           4.0            1.2
# ..  ...              ...            ...           ...            ...
# 49  150   Iris-virginica            5.9           3.0            5.1
# 12   63  Iris-versicolor            6.0           2.2            4.0
# 6    57  Iris-versicolor            6.3           3.3            4.7
# 6   107   Iris-virginica            4.9           2.5            4.5
# 25   26      Iris-setosa            5.0           3.0            1.6
#
#     PetalWidthCm
# 4            1.5
# 8            1.8
# 38           1.3
# 43           1.0
# 14           0.2
# ..           ...
# 49           1.8
# 12           1.0
# 6            1.6
# 6            1.7
# 25           0.2
#
# [150 rows x 6 columns]

# %% [markdown]
# ### `Q-11:` Find out the maximum and minimum sepal width and petal width of Setosa and Versicolor. To do this:
# - First create a dataset with merging the required datasets
# - After that, use `groupby` to create groups based on the "Species" column.
# - Then find out which are asked in this question.
#
#
# The output should be like this:
# ```bash
# Minimum Sepal width of Setosa is 2.3
# Maximum Sepal width of Setosa is 4.4
#
# **************************************************
#
# Minimum Sepal width of Versicolor is 2.0
# Maximum Sepal width of Versicolor is 3.4
#
# **************************************************
# ```

# %%
set['SepalWidthCm'].max()
set['SepalWidthCm'].min()
# Out:
# 2.3

# %%
ver['SepalWidthCm'].max()
ver['SepalWidthCm'].min()
# Out:
# 2.0
